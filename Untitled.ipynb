# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import selectivesearch

def SS(name="menu-0060000-0070000-0004405.png"):
    # loading lena image
    img = cv2.imread("data_image/image0/" + name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # perform selective search
    img_lbl, regions = selectivesearch.selective_search(
        img, scale=500, sigma=0.01, min_size=100)

    candidates = set()
    for r in regions:
        # excluding same rectangle (with different segments)
        if r['rect'] in candidates:
            continue
        # excluding regions smaller than 2000 pixels
        if r['size'] < 2000:
            continue
        # distorted rects
        x, y, w, h = r['rect']
        if w / h > 1.2 or h / w > 1.2:
            continue
        candidates.add(r['rect'])

    # draw rectangles on the original image
    fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
    ax.imshow(img)
    for x, y, w, h in candidates:
        print(x, y, w, h)
        rect = mpatches.Rectangle(
            (x, y), w, h, fill=False, edgecolor='red', linewidth=1)
        ax.add_patch(rect)

    plt.show()

# %%
SS("menu-0090000-0100000-0001958.png")
# Out:
# 123 27 222 232
# 123 83 191 176
# 153 84 132 122
# 0 27 114 100
# 251 174 94 85
# 199 83 115 135

# %%
import os
import numpy as np
path = os.listdir("data_image/image0/")
for i in range(10):
    SS(path[np.random.randint(0, len(path))])
# Out:
# 38 37 157 131
# 0 71 210 188
# 114 162 96 97
# 114 162 53 49
# 248 27 76 88
# 0 0 87 83
# 188 106 124 133
# 0 29 191 167
# 267 48 57 67
# 138 6 186 184
# 188 106 136 153
# 102 6 222 253
# 207 131 87 78
# 207 131 72 78
# 83 114 69 70
# 157 50 117 109
# 268 32 77 65
# 157 50 77 70
# 157 50 108 109
# 63 164 107 95
# 140 140 75 66
# 216 67 102 120
# 208 23 94 97
# 0 0 181 179
# 175 124 86 91
# 132 124 129 120
# 110 58 133 137
# 224 67 94 111
# 154 111 76 91
# 242 143 103 116
# 238 132 107 127
# 181 115 83 95
# 84 71 102 98
# 154 111 110 99
# 11 69 168 153
# 127 97 189 162
# 185 93 160 153
# 51 55 103 107
# 0 24 82 78
# 0 46 104 101
# 176 8 169 143
# 0 24 154 138
# 213 34 132 117
# 184 93 161 153
# 21 51 183 188
# 151 39 194 203
# 31 139 80 71
# 55 99 105 102
# 223 64 122 126
# 151 39 194 220
# 21 51 136 159
# 201 141 108 101
# 151 79 158 163
# 0 26 79 77
# 21 124 90 86
# 205 64 140 126
# 44 61 134 140
# 10 127 77 87
# 154 0 105 89
# 148 64 149 174
# 32 69 109 102
# 210 36 112 111
# ...
